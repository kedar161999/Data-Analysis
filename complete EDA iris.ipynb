# %%
from warnings import filterwarnings
filterwarnings=('ignore')

# %%
import pandas as pd

# %%
df=pd.read_csv("D:/data analyst/sample database/iris.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df=pd.read_csv("D:/data analyst/sample database/iris.csv")
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# #missisng values in dataset

# %%
s = df.isna().sum()

# %%
s
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
s[s>0]
# Out:
# Series([], dtype: int64)

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
cat = list(df.columns[df.dtypes=='object'])
con = list(df.columns[df.dtypes!='object'])

# %%
cat
# Out:
# ['species']

# %%
con
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
df[cat].describe().T
# Out:
#         count unique     top freq
# species   150      3  setosa   50

# %%
df[con].describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %% [markdown]
# UNIVARIENT ANALYTICS

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cat
# Out:
# ['species']

# %%
for i in cat:
    df[i].value_counts().plot(kind='bar', 
                              title=f'Countplot for {i}',
                              figsize=(4,4))
    plt.show()

# %%
con
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
for i in con:
    plt.figure(figsize=(8,4))
    sns.histplot(data=df, x=i, kde=True)
    plt.title(f'Histogram for {i}')    
    plt.show()

# %% [markdown]
# BIAVARIENT DATA ANALYTICS

# %%
# continous vs continous (SCATER PLOT)

# %%
con
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(data=df, x='sepal_length', y='sepal_width')
plt.title('Scatterplot for sepal_length vs sepal_width')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(data=df, x='petal_length', y='petal_width')
plt.title('Scatterplot for petal_length vs petal_width')
plt.grid()
plt.show()

# %% [markdown]
# CORRELATION HITMAP

# %%
df[con].corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(df[con].corr(), annot=True)
plt.show()

# %% [markdown]
# catogorial VS continous(BOX PLOT)

# %%
cat
# Out:
# ['species']

# %%
con
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df, x='species', y='sepal_length')
plt.title('Boxplot for species vs sepal_length')
plt.show()

# %%
for i in con:
    plt.figure(figsize=(10,5))
    sns.boxplot(data=df, x=i, y='species')
    plt.title(f'Boxplot for {i} vs species')
    plt.show()

# %% [markdown]
# CATOGARICAL VS CATOGARICAL

# %%
cat
# Out:
# ['species']

# %%
ctab1 = pd.crosstab(df['species'], df['species'])

# %%
ctab1
# Out:
# species     setosa  versicolor  virginica
# species
# setosa          50           0          0
# versicolor       0          50          0
# virginica        0           0         50

# %%
sns.heatmap(ctab1, annot=True)
# Out:
# <Axes: xlabel='species', ylabel='species'>

# %%
sns.pairplot(data=df)
